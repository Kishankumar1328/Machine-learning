# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishankumar1328/Machine-learning/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_excel("/content/Karur_Weather_Data_Jan2021_Jul2024.xlsx")
df
# Out:
#    Month/Year  Average Temperature (°C)  Total Rainfall (mm)  \
# 0    Jan 2021                      33.1                177.0
# 1    Feb 2021                      32.0                219.0
# 2    Mar 2021                      26.0                 93.6
# 3    Apr 2021                      34.2                119.5
# 4    May 2021                      32.1                 63.0
# 5    Jun 2021                      35.0                 55.9
# 6    Jul 2021                      26.5                283.3
# 7    Aug 2021                      33.7                221.9
# 8    Sep 2021                      26.6                147.1
# 9    Oct 2021                      31.2                 68.2
# 10   Nov 2021                      26.2                 76.3
# 11   Dec 2021                      33.5                 17.4
# 12   Jan 2022                      33.1                130.3
# 13   Feb 2022                      30.7                 93.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Month/Year                 43 non-null     object
#  1   Average Temperature (°C)   43 non-null     float64
#  2   Total Rainfall (mm)        43 non-null     float64
#  3   Average Humidity (%)       43 non-null     float64
#  4   Average Wind Speed (km/h)  43 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 1.8+ KB

# %%
df.memory_usage(deep=True)
# Out:
# Index                         128
# Month/Year                   2795
# Average Temperature (°C)      344
# Total Rainfall (mm)           344
# Average Humidity (%)          344
# Average Wind Speed (km/h)     344
# dtype: int64

# %%
x=df[["Average Humidity (%)","Average Wind Speed (km/h)"]]
y=df["Average Humidity (%)"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.score(x_test,y_test)
# Out:
# 1.0

# %%
lm.score(x_train,y_train)
# Out:
# 1.0

# %%
y_pred=lm.predict(x_test)

# %%
plt.scatter(y_test, y_pred, color="blue", alpha=0.3)

plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')
